# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv(r"Adozione Dati Puliti.csv")

# %%
df
# Out:
#       Unnamed: 0                                           Crop  \
# 0              0     Genetically engineered (GE) corn varieties
# 1              1     Genetically engineered (GE) corn varieties
# 2              2     Genetically engineered (GE) corn varieties
# 3              3     Genetically engineered (GE) corn varieties
# 4              4     Genetically engineered (GE) corn varieties
# ...          ...                                            ...
# 1415        2599  Genetically engineered (GE) soybean varieties
# 1416        2600  Genetically engineered (GE) soybean varieties
# 1417        2601  Genetically engineered (GE) soybean varieties
# 1418        2602  Genetically engineered (GE) soybean varieties
# 1419        2603  Genetically engineered (GE) soybean varieties
#
#                          Variety  Year         State  Value
# 0     Insect-resistant (Bt) only  2000      Illinois     13
# 1     Insect-resistant (Bt) only  2000       Indiana      7
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Crop', 'Variety', 'Year', 'State', 'Value'], dtype='object')

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df
# Out:
#                                                Crop  \
# 0        Genetically engineered (GE) corn varieties
# 1        Genetically engineered (GE) corn varieties
# 2        Genetically engineered (GE) corn varieties
# 3        Genetically engineered (GE) corn varieties
# 4        Genetically engineered (GE) corn varieties
# ...                                             ...
# 1415  Genetically engineered (GE) soybean varieties
# 1416  Genetically engineered (GE) soybean varieties
# 1417  Genetically engineered (GE) soybean varieties
# 1418  Genetically engineered (GE) soybean varieties
# 1419  Genetically engineered (GE) soybean varieties
#
#                          Variety  Year         State  Value
# 0     Insect-resistant (Bt) only  2000      Illinois     13
# 1     Insect-resistant (Bt) only  2000       Indiana      7
# 2     Insect-resistant (Bt) only  2000          Iowa     23
# 3     Insect-resistant (Bt) only  2000        Kansas     25
# ...

# %%
df=df.set_index(['State', 'Year'], append=True)

# %%
df
# Out:
#                                                                  Crop  \
#      State        Year
# 0    Illinois     2000     Genetically engineered (GE) corn varieties
# 1    Indiana      2000     Genetically engineered (GE) corn varieties
# 2    Iowa         2000     Genetically engineered (GE) corn varieties
# 3    Kansas       2000     Genetically engineered (GE) corn varieties
# 4    Michigan     2000     Genetically engineered (GE) corn varieties
# ...                                                               ...
# 1415 Ohio         2020  Genetically engineered (GE) soybean varieties
# 1416 South Dakota 2020  Genetically engineered (GE) soybean varieties
# 1417 Wisconsin    2020  Genetically engineered (GE) soybean varieties
# 1418 Other States 2020  Genetically engineered (GE) soybean varieties
# 1419 U.S.         2020  Genetically engineered (GE) soybean varieties
#
#                                            Variety  Value
#      State        Year
# ...

# %%
df.loc[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Illinois'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-a02c171e73cf> in <module>
# ----> 1 df.loc["Illinois"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
# ...
